# %% [markdown]
# # **Project Name**    -  Exploratory Data Analysis of Hotel Booking Analysis
# **EDA Based on the data of Hotel Bookings using the Python libraries Matplolib And Seaborn**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name**            - Pratik Shinde

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyse the data to discover important factors that govern the bookings.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The problem at hand revolves around understanding the dynamics of hotel bookings to identify key factors influencing booking patterns, cancellations, and customer preferences. Specifically, the goal is to analyze a comprehensive hotel booking dataset containing information about booking dates, length of stay, guest demographics, and other relevant attributes for both city hotels and resort hotels. By exploring this dataset, we aim to uncover insights that can help optimize booking strategies, reduce cancellations, enhance customer experience, and inform revenue management decisions.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

from google.colab import drive
drive.mount("/content/drive")

path="/content/drive/MyDrive/Datasets/Hotel_Bookings.csv"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df=pd.read_csv(path)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * Total number of entries: 119,390
# * Total number of columns: 32
# * There are some duplicate values.
# * Data types include float64, int64, and object (strings)
# * Some columns have missing values, which we will handle during data wrangling.

# %% [markdown]
# ----

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Index	Variable	Description**
#
#
# ---
# 1.	hotel	- Type of hotel (Resort Hotel, City Hotel)
# 2.	is_canceled -	Reservation cancellation status (0 = not canceled, 1 = canceled)
# 3.	lead_time -	Number of days between booking and arrival
# 4.	arrival_date_year -	Year of arrival
# 5.	arrival_date_month -	Month of arrival
# 6.	arrival_date_week_number -	Week number of the year for arrival
# 7.	arrival_date_day_of_month -	Day of the month of arrival
# 8.	stays_in_weekend_nights -	Number of weekend nights (Saturday and Sunday) the guest stayed or booked
# 9.	stays_in_week_nights -	Number of week nights the guest stayed or booked
# 10.	adults -	Number of adults
# 11.	children -	Number of children
# 12.	babies -	Number of babies
# 13.	meal -	Type of meal booked (BB, FB, HB, SC, Undefined)
# 14.	country -	Country of origin of the guest
# 15.	market_segment -	Market segment designation
# 16.	distribution_channel -	Booking distribution channel
# 17.	is_repeated_guest -	If the guest is a repeat customer (0 = not repeated, 1 = repeated)
# 18.	previous_cancellations -	Number of previous bookings that were canceled by the customer
# 19.	previous_bookings_not_canceled -	Number of previous bookings that were not canceled by the customer
# 20.	reserved_room_type -	Type of reserved room
# 21.	assigned_room_type -	Type of assigned room
# 22.	booking_changes -	Number of changes made to the booking
# 23.	deposit_type -	Type of deposit made (No Deposit, Refundable, Non Refund)
# 24.	agent -	ID of the travel agent responsible for the booking
# 25.	company -	ID of the company responsible for the booking
# 26.	days_in_waiting_list -	Number of days the booking was in the waiting list
# 27.	customer_type -	Type of customer (Transient, Contract, Transient-Party, Group)
# 28.	adr -	Average Daily Rate
# 29.	required_car_parking_spaces -	Number of car parking spaces required
# 30.	total_of_special_requests -	Number of special requests made
# 31.	reservation_status -	Last reservation status (Check-Out, Canceled, No-Show)
# 32.	reservation_status_date -	Date of the last reservation status
#
#
#
# ---

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.describe(include='object').columns:
  print(col)
  print(f"{df[col].unique()}")
  print("-"*75)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ---------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ---------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ---------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#lets drop duplicate values
df.drop_duplicates(inplace=True)

# %%
#Drop the columns which contains more null values
df.drop(columns=['agent','company'],axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# let's change the column name for better understand and readability
df.columns = ['Hotel', 'Canceled', 'LeadTime', 'ArrivingYear', 'ArrivingMonth', 'ArrivingWeek','ArrivingDate', 'WeekendStay',
              'WeekStay', 'Adults', 'Children', 'Babies', 'Meal','Country', 'Segment', 'DistChannel','RepeatGuest', 'PrevCancel',
              'PrevBook', 'BookRoomType','AssignRoomType', 'ChangeBooking', 'DepositType', 'WaitingDays',
              'CustomerType', 'ADR','ParkSpace', 'SpecialRequest','Reservation', 'ReservationDate']

# %%
df.columns
# Out:
# Index(['Hotel', 'Canceled', 'LeadTime', 'ArrivingYear', 'ArrivingMonth',
#        'ArrivingWeek', 'ArrivingDate', 'WeekendStay', 'WeekStay', 'Adults',
#        'Children', 'Babies', 'Meal', 'Country', 'Segment', 'DistChannel',
#        'RepeatGuest', 'PrevCancel', 'PrevBook', 'BookRoomType',
#        'AssignRoomType', 'ChangeBooking', 'DepositType', 'WaitingDays',
#        'CustomerType', 'ADR', 'ParkSpace', 'SpecialRequest', 'Reservation',
#        'ReservationDate'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Canceled      LeadTime  ArrivingYear  ArrivingWeek  ArrivingDate  \
# count  86940.000000  86940.000000  86940.000000  86940.000000  86940.000000
# mean       0.275903     80.193375   2016.211824     26.841477     15.818024
# std        0.446971     86.100147      0.686016     13.654505      8.834469
# min        0.000000      0.000000   2015.000000      1.000000      1.000000
# 25%        0.000000     12.000000   2016.000000     16.000000      8.000000
# 50%        0.000000     50.000000   2016.000000     27.000000     16.000000
# 75%        1.000000    125.000000   2017.000000     37.000000     23.000000
# max        1.000000    737.000000   2017.000000     53.000000     31.000000
#
#         WeekendStay      WeekStay        Adults      Children        Babies  \
# count  86940.000000  86940.000000  86940.000000  86940.000000  86940.000000
# mean       1.007396      2.628744      1.878525      0.139211      0.010835
# ...

# %%
#lets check if there are outliers present in the data set
outliers=['Adults','Children','Babies','WaitingDays','ADR','LeadTime']
plt.figure(figsize=(14, 10))
for i, outliers in enumerate(outliers, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(x=outliers, data=df)
    plt.tight_layout()

plt.show()

# %% [markdown]
# **Their are some Outliers present in the data set lets make a soretd dataset without outliers .**

# %%
df=df[df['Adults']<50]
df=df[df['Children']<10]
df=df[df['Babies']<9]
df=df[df['WaitingDays']<350]
df=df[df['ADR']<5000]
df=df[df['LeadTime']<700]

# %%
df.describe()
# Out:
#            Canceled      LeadTime  ArrivingYear  ArrivingWeek  ArrivingDate  \
# count  86924.000000  86924.000000  86924.000000  86924.000000  86924.000000
# mean       0.275839     80.141307   2016.211921     26.840320     15.818059
# std        0.446938     85.972425      0.686013     13.654371      8.834575
# min        0.000000      0.000000   2015.000000      1.000000      1.000000
# 25%        0.000000     12.000000   2016.000000     16.000000      8.000000
# 50%        0.000000     50.000000   2016.000000     27.000000     16.000000
# 75%        1.000000    125.000000   2017.000000     37.000000     23.000000
# max        1.000000    629.000000   2017.000000     53.000000     31.000000
#
#         WeekendStay      WeekStay        Adults      Children        Babies  \
# count  86924.000000  86924.000000  86924.000000  86924.000000  86924.000000
# mean       1.007386      2.628630      1.877353      0.139122      0.010618
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86924 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Hotel            86924 non-null  object
#  1   Canceled         86924 non-null  int64
#  2   LeadTime         86924 non-null  int64
#  3   ArrivingYear     86924 non-null  int64
#  4   ArrivingMonth    86924 non-null  object
#  5   ArrivingWeek     86924 non-null  int64
#  6   ArrivingDate     86924 non-null  int64
#  7   WeekendStay      86924 non-null  int64
#  8   WeekStay         86924 non-null  int64
#  9   Adults           86924 non-null  int64
#  10  Children         86924 non-null  float64
#  11  Babies           86924 non-null  int64
#  12  Meal             86924 non-null  object
#  13  Country          86924 non-null  object
#  14  Segment          86924 non-null  object
#  15  DistChannel      86924 non-null  object
#  16  RepeatGuest      86924 non-null  int64
# ...

# %%
df['ReservationDate']=pd.to_datetime(df['ReservationDate'])
df['ArrivingDate']=pd.to_datetime(df['ArrivingDate'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * As we have some columns containing excessive null values soo we drop those columns('agent', 'company').
# * we also have some missing values in the country so we also removed them.
# * changed the column name for better understand and readability.
# * removed the outliers for better data vizualization.

# %% [markdown]
# -------

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # **Correlation Heatmap**

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# * The correlation heatmap visualizes the pairwise correlation between different numerical features in the dataset.
# * It provides a quick overview of the strength and direction of the relationships between variables.
# * Positive correlations are indicated by values closer to 1, while negative correlations are indicated by values closer to -1. A value of 0 indicates no correlation.
# * High positive correlations between certain features may suggest redundancy or multicollinearity, while negative correlations may suggest inverse relationships.

# %% [markdown]
# ---

# %% [markdown]
# # **Which type of hotel is mostly prefered by the guests?**

# %%
print(df['Hotel'].value_counts())
print("-"*50)
print(df['Hotel'].value_counts(normalize=True))
# Out:
# City Hotel      53407
# Resort Hotel    33517
# Name: Hotel, dtype: int64
# --------------------------------------------------
# City Hotel      0.61441
# Resort Hotel    0.38559
# Name: Hotel, dtype: float64

# %%
df['Hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', figsize=(8,6),fontsize=20)
plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %% [markdown]
# From the above chart, we can see that there are more reservations made in city hotels than in resort hotels.
#
# Pie charts help us to visualise easily how much the percentage is it's 61% for city hotels and 38% for resort hotels.

# %% [markdown]
# ---

# %% [markdown]
# # **Lets see the reservation status**

# %%
print(df['Canceled'].value_counts())
print("-"*50)
print(df['Canceled'].value_counts(normalize=True))
# Out:
# 0    62947
# 1    23977
# Name: Canceled, dtype: int64
# --------------------------------------------------
# 0    0.724161
# 1    0.275839
# Name: Canceled, dtype: float64

# %%
cols = ['gold', 'lightcoral']
df['Canceled'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True, colors=cols,labels=['Not Canceled','Canceled'])
plt.title('chart for cancelation status')
# Out:
# Text(0.5, 1.0, 'chart for cancelation status')

# %% [markdown]
# This visualization is a good choice for understanding the proportion of canceled bookings relative to the total number of bookings. It provides a clear visual representation of the cancellation rate, making it easy to interpret for stakeholders or anyone reviewing your analysis.

# %% [markdown]
# From the chart, we can see that around 27.6% of bookings were canceled, while the majority, about 72.4%, were not canceled. This insight is valuable for understanding the overall cancellation behavior in your dataset and could inform strategies for managing booking cancellations in the future.

# %% [markdown]
# ----------------------

# %% [markdown]
# # **Lets see the cancelation rate in Resort Hotel vs City Hotel**

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Hotel',hue='Canceled',data=df,palette='Set2')
plt.title('Cancelation Rate in Resort Hotel vs City Hotel')
plt.legend(['Not Canceled','Canceled'])
plt.show()

# %% [markdown]
# The chart  created illustrates the cancellation rates in Resort Hotels versus City Hotels. This visualization is particularly useful for comparing the cancellation behavior between these two types of accommodations.

# %% [markdown]
# *  Resort Hotel: The cancellation rate seems lower compared to City Hotels. This
# could imply that guests booking at Resort Hotels are less likely to cancel their reservations.
# *  City Hotel: Conversely, City Hotels appear to have a higher cancellation rate compared to Resort Hotels. This insight might suggest that there are factors specific to City Hotels that lead to a higher propensity for cancellations.

# %% [markdown]
# ---

# %% [markdown]
# #  **ADR comparison of city hotel vs resort hotel based on time period**

# %%
resort_hotel=df[df['Hotel']=='Resort Hotel']
city_hotel=df[df['Hotel']=='City Hotel']

# %%
resort_hotel=resort_hotel.groupby('ReservationDate')[['ADR']].mean()
city_hotel=city_hotel.groupby('ReservationDate')[['ADR']].mean()

# %%
plt.figure(figsize=(12, 6))
plt.bar(resort_hotel.index, resort_hotel['ADR'], width=0.4, align='center', label='Resort Hotel')
plt.bar(city_hotel.index, city_hotel['ADR'], width=0.4, align='edge', label='City Hotel')
plt.xlabel('Time Period')
plt.ylabel('ADR')
plt.title('Average Daily Rate Comparison')
plt.legend()
plt.show()

# %% [markdown]
# The chart chosen compares the average daily rate (ADR) between Resort Hotels and City Hotels over different time periods. This visualization provides insights into how ADR varies over time for these two types of accommodations.

# %% [markdown]
# *  Resort Hotel: The ADR fluctuates over time, showing variations in pricing. There may be seasonal trends or other factors influencing the ADR for Resort Hotels.
# *  City Hotel: Similarly, City Hotels also exhibit fluctuations in ADR over different time periods. Understanding these variations can help identify peak seasons or events that impact pricing.

# %% [markdown]
# ---

# %% [markdown]
# #**Reservation status based on month**

# %%
df['Month']=df['ReservationDate'].dt.month
plt.figure(figsize=(15,6))
sns.countplot(x='Month',hue='Canceled',data=df,palette='husl')
plt.title('Reservation status per month ')
plt.legend(['Not Canceled','Canceled'])
plt.show()

# %% [markdown]
# The chart you've chosen visualizes the reservation status per month, distinguishing between canceled and not canceled bookings. This visualization is particularly useful for understanding how the cancellation behavior varies across different months of the year.

# %% [markdown]
# Monthly Trends: The chart allows us to observe any patterns or trends in cancellation rates over the months. For example, there may be certain months with higher cancellation rates compared to others.
#
# As we can see the month of JULY,AUGUST has the most reservation among the year.

# %% [markdown]
# ---

# %% [markdown]
# # **ADR when the Reservation got canceled based on month**

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Month',y='ADR',data=df[df['Canceled']==1].groupby('Month')[['ADR']].sum().reset_index(),palette='Set2')
plt.title('ADR per Month')
plt.show()

# %% [markdown]
# we've chosen a bar chart to visualize the average daily rate (ADR) per month for canceled bookings. This visualization helps understand how the ADR varies across different months for bookings that were canceled.

# %% [markdown]
# As we can see the average daily rate for each month when the reservation was canceled , we can see at the year end the ADR was less

# %% [markdown]
# ----

# %% [markdown]
# # **Does the Booked Room type was assigned to the coustomer ?**

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='BookRoomType',data=df,palette='tab10')
plt.show()

plt.figure(figsize=(10,4))
sns.countplot(x='AssignRoomType',data=df,palette='tab10')
plt.show()

# %% [markdown]
# we've chosen count plots to visualize the distribution of room types for booked rooms (BookRoomType) and assigned rooms (AssignRoomType).

# %% [markdown]
# *  Room Type Distribution: These charts provide insights into the distribution of room types for both booked and assigned rooms.
# *  As we see the most preferred room type is 'A' & 'D' and as per the request of the customers they have been Assign the same room type they have booked.

# %% [markdown]
# ---

# %% [markdown]
# # **Which segment has the most booking, does the same segment has most canceled booking ?**

# %%
Cancelled_Data=df[df['Canceled']==1]
Not_Cancelled_Data=df[df['Canceled']==0]

# %%
segment_order = df['Segment'].unique()
plt.figure(figsize=(10,4))
plt.title('Booking per Segement')
sns.countplot(x='Segment',data=df,palette='tab10', order=segment_order)
plt.show()
plt.figure(figsize=(10,4))
plt.title('Canceled booking per segement')
sns.countplot(x='Segment',data=Cancelled_Data,palette='tab10', order=segment_order)
plt.show()

# %% [markdown]
# we've chosen count plots to visualize the distribution of bookings per segment (Segment) and canceled bookings per segment (Segment).

# %% [markdown]
# *  Booking Distribution: The first chart illustrates the distribution of bookings across different segments. It helps understand the popularity of each segment among guests.
# *  Canceled Booking Distribution: The second chart focuses on canceled bookings, providing insights into which segments are more prone to cancellations. This information is valuable for identifying segments that may require targeted strategies to reduce cancellations.
#
# *  AS we can see most of the booking was done by the online travel agents , as well as the most booking was also cancled by the online travel agents

# %% [markdown]
# ---

# %% [markdown]
# # **By which distrubtion channel this is done**

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='DistChannel',data=df,palette="husl")
plt.show()

# %% [markdown]
# The chart we've chosen, a count plot showing the distribution of bookings by distribution channel, provides valuable insights into how customers are booking their stays. This visualization helps identify the most popular channels through which bookings are made, enabling the hotel to focus its marketing efforts and resources accordingly..

# %% [markdown]
# Online travel agents (OTAs) appear to be the most preferred channel for booking, indicating the significant role they play in driving reservations for the hotel.
# Direct bookings through the hotel's website or other direct channels may also be substantial, suggesting a strong brand presence or loyalty among customers.

# %% [markdown]
# ---

# %% [markdown]
# # **Duration between booking and arival.**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='LeadTime', bins=30, kde=True)
plt.xlabel('Lead Time')
plt.ylabel('Frequency')
plt.title('Distribution of Lead Time')
plt.show()

# %% [markdown]
# You've chosen a histogram to visualize the distribution of lead time (LeadTime).

# %% [markdown]
# Lead Time Distribution: This histogram provides insights into the distribution of lead time, which is the duration between booking and arrival. Understanding the distribution of lead time can help hotels anticipate booking patterns and plan resources accordingly.
#
#
# We can clearly see that the frequency of customers are more while the lead time is less,their is not much  duration gab between booking and arrival

# %% [markdown]
# ---

# %% [markdown]
# # **Does more waiting day affect the reservation ?**

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Canceled', y='WaitingDays', data=df,palette='rocket')
plt.xlabel('Cancelled Reservation')
plt.ylabel('Average Waiting Days')
plt.title('Correlation between Waiting Days and Cancelled Reservations')
plt.show()

# %% [markdown]
# This bar plot visualizes the correlation between waiting days and canceled reservations. It's an effective choice because it allows us to compare the average waiting days for both canceled and not canceled reservations, providing insights into how waiting time impacts cancellation behavior.

# %% [markdown]
# Canceled Reservations: The average waiting days for canceled reservations appear to be slightly higher compared to reservations that were not canceled. This suggests that longer waiting periods might influence the likelihood of a reservation being canceled. Customers may be more inclined to cancel their bookings if they experience longer wait times.

# %% [markdown]
# ---

# %% [markdown]
# # **Which is the deposit type most preferred by the customers**

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='DepositType',data=df,palette='YlGn')
# Out:
# <Axes: xlabel='DepositType', ylabel='count'>

# %% [markdown]
# The chart we've selected visualizes the count of different deposit types using a count plot. This type of plot is suitable for categorical data and provides a clear overview of the distribution of deposit types in the dataset.

# %% [markdown]
# We can observe the frequency of each deposit type, which helps in understanding the preferred deposit methods among customers.
# By analyzing the distribution, we can identify which deposit type is most commonly used or if there's a significant imbalance among the different deposit types.

# %% [markdown]
# As we can see the deposit type, No deposit is taken from the customer while booking this might be why the booking gets cancelled.

# %% [markdown]
# ---

# %% [markdown]
# # **By which country the Cancelation rate is more**

# %%
top_10_country=Cancelled_Data['Country'].value_counts()[:10]
plt.figure(figsize=(8, 8))
plt.pie(top_10_country, labels=top_10_country.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Cancelled Bookings by Country (Top 10)')
plt.axis('equal')
plt.show()

# %% [markdown]
# The pie chart you've chosen visualizes the distribution of canceled bookings by country for the top 10 countries. This type of chart effectively presents the proportion of canceled bookings from each country relative to the total number of canceled bookings.

# %% [markdown]
# The chart provides a clear overview of which countries contribute the most to canceled bookings among the top 10.
#
#
# By analyzing the distribution, you can identify any significant contributors to the cancellation rate and potentially explore reasons behind the cancellations from specific countries.

# %% [markdown]
# We can see in the above chart that the most cancelled bookings are from Portugal
# followed by the United Kingdom of Great Britain and Spain

# %% [markdown]
# ---

# %% [markdown]
# ## **Conclusion & Bussiness objective solution**

# %% [markdown]
# In addition, some key insights from the analysis include:
#
# * Guests showed a preference for City hotels, making it the busiest type of hotel.
# * Approximately 27.5% of all bookings were cancelled, highlighting the need for cancellation rate optimization strategies.
# * Only 3.9% of guests revisited the hotels, indicating a low retention rate that could be improved through targeted marketing and enhanced customer experience initiatives.
# * Most bookings for City and Resort hotels were made in 2016, indicating potential trends in booking behavior over time.
# * Most of the booking was done in the month of july ,august.
# * City hotels generated more revenue than Resort hotels, with higher average ADR (Average Daily Rate).
# * City hotels had a higher booking cancellation rate of almost 30%, indicating the importance of focusing on cancellation reduction strategies in these establishments.
# * Resort hotels had a higher average lead time, suggesting potential differences in booking behavior and planning between City and Resort hotels.
# * Waiting time was higher for City hotels compared to Resort hotels, indicating that City hotels may be experiencing higher demand or occupancy rates, leading to longer wait times.
# * people preferred No deposit over refundable or non-refundable.
# * online travel agents have made more reservations than any other.
# * Approximately 19% of people did not cancel their bookings despite not getting the reserved room, while only 2.5% cancelled their bookings, highlighting potential areas for improvement in room allocation and management processes.

# %% [markdown]
# **1. Reducing Cancellations:**
#
# * Focus on reducing cancellations, especially in City Hotels, by understanding the reasons behind them. Consider offering flexible booking options or incentives for non-cancellable bookings to encourage guests to commit to their reservations.
#
# **2. Maximizing Revenue:**
#
# * Adjust pricing strategies based on demand fluctuations and seasonal trends. Utilize data on lead time distribution to optimize room availability and pricing, ensuring maximum revenue generation.
#
# **3. Targeted Marketing:**
#
# *  marketing efforts and service offerings based on customer segments to enhance satisfaction and build loyalty. Understanding the preferences and behaviors of different customer segments can help tailor strategies to better meet their needs.
#
# **4. Enhance Customer Experience:**
#
# * Analyze deposit type preferences and consider offering incentives for non-refundable bookings to reduce cancellations.
# * Streamline booking processes and minimize waiting times to improve the overall customer experience. Providing a seamless booking experience can reduce frustration and potential cancellations.
#
# **5. Addressing International Markets:**
#
# * Investigate the reasons behind high cancellation rates from specific countries, such as Portugal, and implement targeted initiatives to mitigate cancellations. Understanding the unique challenges faced by international guests can help tailor strategies to better serve their needs.
#
# **6. Forecasting and Planning:**
#
# * Use historical data and predictive analytics to forecast booking trends and optimize resource allocation. By accurately predicting booking patterns, hotels can optimize staffing, inventory management, and other resources to meet demand effectively.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
